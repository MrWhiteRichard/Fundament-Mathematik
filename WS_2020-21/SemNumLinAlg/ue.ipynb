# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xvals = np.arange(-5,5,0.01)
def interpolation(x):
    return (1/4) * x **2 + x + 5/4 - (1/2) * x ** 3
yvals = interpolation(xvals)

# %%
plt.plot(xvals, yvals)
