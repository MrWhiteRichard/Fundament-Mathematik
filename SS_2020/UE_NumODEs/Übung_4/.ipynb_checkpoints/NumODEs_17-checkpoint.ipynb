# %% [markdown]
# **Aufgabe 17:**
#
# Implementieren Sie das implizite Euler Verfahren unter Verwendung des Newton-Verfahrens zur Lösung des nichtlinearen Gleichungssystems. Der Algorithmus soll als Input-Parameter einen Vektor von Stützstellen $t$, einen Startwert $y_0$, die rechte Seite und Ableitung der rechten Seite $f$ bzw. $\frac{\partial}{\partial t} f$ sowie eine geeignete Abbruchbedinung für das Newton Verfahren (Toleranz und/oder maximale Anzahl an Interationen) akzeptieren.
#
# Testen Sie das Verfahren an folgenden Anfangswertproblemen: Sei $Y = (y_1, y_2)^T$ die Lösung des Anfangswertproblems
#
# \begin{align} \tag{1}
#     Y^\prime(t)
#     =
#     \begin{pmatrix}
#         -2 &  1 \\
#          1 & -2
#     \end{pmatrix}
#     Y(t)
#     +
#     \begin{pmatrix}
#         2 \sin{t} \\
#         2 (\cos{t} - \sin{t})
#     \end{pmatrix},
#     \quad
#     t \geq 0,
#     \quad
#     Y(0)
#     =
#     \begin{pmatrix}
#         2 \\
#         3
#     \end{pmatrix}.
# \end{align}
#
# Sei $Z = (z_1, z_2)^T$ die Lösung des Anfangswertproblems
#
# \begin{align} \tag{2}
#     Z^\prime(t)
#     =
#     \begin{pmatrix}
#         -2   &  1 \\
#          998 & -999
#     \end{pmatrix}
#     Z(t)
#     +
#     \begin{pmatrix}
#         2 \sin{t} \\
#         999 (\cos{t} - \sin{t})
#     \end{pmatrix},
#     \quad
#     t \geq 0,
#     \quad
#     Z(0)
#     =
#     \begin{pmatrix}
#         2 \\
#         3
#     \end{pmatrix}.
# \end{align}
#
# Vergleichen Sie dabei auch mit den Ergebnissen und Schrittweiten des eingebetteten Runge-Kutta Verfahren RK5(4) aus Aufgabe 15. Verwenden Sie dazu die Parameter $t \in [0, 10]$, $\rho = 0.7$, $\eta = 1.5$, $\text{tol} = 10^{-6}$, $h_{\text{min}} = 10^{-10}$.

# %%
import numpy as np
from scipy.optimize import fsolve
import matplotlib.pyplot as plt
from timeit import default_timer as timer

# %%
def newton(F, DF, x_0, tol = 1e-6, t_max = 1e16):

    """
        This function implements the Newton-Method
        (from Nannen, Numerik A, Algorithmus 7.12).

        F ....... We search for x such that F(x) = 0.
        DF ...... Jacobian Matrix of F
        x_0 ..... where the iteration starts
        tol ..... tolerance for accuracy of F(x)
        t_max ... maximum iterations for Newton-Method
    """

    x = [x_0]
    Delta_x = [np.linalg.solve(DF(x[0]), -F(x[0]))]
    x += [x[0] + Delta_x[0]]
    t = 0

    while True:

        t += 1
        Delta_x += [np.linalg.solve(DF(x[t]), -F(x[t]))]
        x += [x[t] + Delta_x[t]]

        q_t = np.linalg.norm(Delta_x[t]) / np.linalg.norm(Delta_x[t-1])

        if q_t >= 1:
            print("STOP: Newton-Verfahren konvergiert nicht.")
            return None

        if q_t / (1 - q_t) * np.linalg.norm(Delta_x[t]) <= tol or t > t_max:
            return x[t+1]

# %%
def implicit_euler(t, y_0, f, f_y, tol = 1e-6, counter_max = 1e16):

    """
        This function implements the implicit Euler-Method.

        t ............. time steps
        y_0 ........... initial value at t_0 for solution
        f ............. right hand side
        f_y............ derivative with respect to y of right hand side
        tol ........... tolerance for accuracy of F(x)
        counter_max ... maximum iterations for Newton-Method
    """

    # dimension of range of f
    n = len(y_0)

    # t = t_0, ..., t_N
    N = len(t) - 1

    # distance between time steps
    h = t[1::] - t[:-1:]

    # approximated solution
    y = [y_0]

    for ell in range(N):

        F_ell  = lambda y_new: y_new - (y[-1] + h[ell] * f(t[ell+1], y_new))
        DF_ell = lambda y_new: np.eye(n, n) - h[ell] * f_y(t[ell+1], y_new)

#         guess = y[-1]
        guess = y[-1] + h[ell] * f(t[ell], y[-1])

#         y_new = newton(F_ell, DF_ell, guess, tol, counter_max)
        y_new = fsolve(F_ell, guess, xtol = tol)

#         print("Test ...", y_new == y[-1] + h[ell] * f(t[ell+1], y_new))
        y += [y_new]

    y = np.array(y).transpose()

    return y

# %%
def test_implicit_euler(f, f_y, y_0, name = "y"):

    """
        This function tests the implicit Euler-Method.

        f ...... right hand side
        f_y..... derivative with respect to y of right hand side
        y_0 .... initial value at t_0 for solution
        name ... that appears on graph
    """

    T = 10
    dt = 0.01
    t = np.arange(0, T, dt)

    y = implicit_euler(t, y_0, f, f_y)

    plt.plot(t, y[0], label = "$" + name + "_1(t)$")
    plt.plot(t, y[1], label = "$" + name + "_2(t)$")

    plt.legend()
    plt.xlabel("$t$")

    plt.grid(linestyle = ":")
    plt.suptitle("Implicit Euler-Method")
    plt.show()

# %%
def practical_adaptive_algorithm(t_0, T, y_0, f, c, A, b_1, b_2, p, tau, h, h_min, lambda_, rho):

    """
        This function implements the Practical adaptive algorithm
        (from Nannen, Numerics of differential equations, Algorithm 2.35).

        t_0 ... lower bound of interval [t_0, T]
        T ..... upper bound of interval [t_0, T]
        y_0 ... initial value
        f ..... right hand side

        c, A, b_1 ... butcher tableau of           explicit runge-kutta one-step method of order p
        c, A, b_2 ... butcher tableau of auxiliary explicit runge-kutta one-step method of order p+1
        p ........... -

        tau ....... tolerance
        h ......... initial time-step size
        h_min ..... minimal time-step size
        lambda_ ... conformity factor
        rho ....... safety factor
    """

    m = len(c)

    t = [t_0]
    y = [y_0]
    h_array = [0]

    print("initiating practical adaptive algorithm ...", "\n")
    start = timer()

    print("current status ...", round(t[-1]/T * 100, 2), "%")
    print("current time .....", round(timer() - start), "sec")
    print("")
    stop = timer()

    while True:

        # status update each second
        if timer() - stop >= 1:
            print("current status ...", round(t[-1]/T * 100, 2), "%")
            print("passed time ......", round(timer() - start), "sec")
            print("")
            stop = timer()

        h = min(T - t[-1], max(h_min, h))

        k = np.zeros((m, 2))

        for i in range(m):
            k[i] = f(t[-1] + c[i] * h, y[-1] + h * (A[i][:i] @ k[:i]))

        F_1 = b_1 @ k
        F_2 = b_2 @ k

        H  = rho * (tau / (np.linalg.norm(F_1 - F_2)))**(1/p) * h

        if h <= H or h <= h_min:

            t += [t[-1] + h]
            h_array += [h]
            y += [y[-1] + h * F_2]

            if t[-1] < T:
                h = min(H, lambda_ * h)

        else:
            h = min(H, h / lambda_)

        if t[-1] >= T:

            t = np.array(t)
            h = np.array(h_array)
            y = np.array(y).transpose()

            return t, h, y

# %%
def test_practical_adaptive_algorithm(f, y_0, name = "y"):

    """
        This function tests the implicit Euler-Method.

        f ...... right hand side
        y_0 .... initial value at t_0 for solution
        name ... that appears on graph
    """

    t_0 = 0
    T   = 10

    rho = 0.7
    eta = 1.5

    tau   = 1e-6
    h_min = 1e-10

    h = 1e-6

    # Butcher tableau - RK5(4)
    A  = np.array([[0,           0,          0,           0,        0,            0,        0   ],
                   [1    /5,     0,          0,           0,        0,            0,        0   ],
                   [3    /40,    9    /40,   0,           0,        0,            0,        0   ],
                   [44   /45,   -56   /15,   32   /9,     0,        0,            0,        0   ],
                   [19372/6561, -25360/2187, 64448/6561, -212/729,  0,            0,        0   ],
                   [9017 /3168, -355  /33,   46732/5247,  49 /176, -5103 /18656,  0,        0   ],
                   [35   /384,   0,          500  /1113,  125/192, -2187 /6784,   11 /84,   0   ]])
    b_1 = np.array([35   /384,   0,          500  /1113,  125/192, -2187 /6784,   11 /84,   0   ])
    b_2 = np.array([5179 /57600, 0,          7571 /16695, 393/640, -92097/339200, 187/2100, 1/40])
    c   = np.array([0,           1    /5,    1    /10,    4  /5,    8    /9,      1,        1   ])
    p   = 4

    t, h, y = practical_adaptive_algorithm(t_0, T, y_0, f, c, A, b_1, b_2, p, tau, h, h_min, eta, rho)

    # ---------------- #

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

    ax1.plot(t, y[0], label = "$" + name + "_1(t)$")
    ax1.plot(t, y[1], label = "$" + name + "_2(t)$")

    ax1.legend()
    ax1.set_xlabel("$t$")

    ax1.grid(linestyle = ":")

    ax2.plot(t, h, '--', label = "Schrittweite", color = "black", linewidth = 1)
    ax2.set_xlabel("$t$")
    ax2.set_ylabel("Schrittweite ($h$)")
    ax2.grid(linestyle = ':')

    plt.suptitle("Practical adaptive algorithm")
    plt.show()

    # ---------------- #

    fig = plt.figure(figsize = (15, 5))

    plt.plot(t, y[0] / max(y[0]), label = "$" + name + "_1(t)$")
    plt.plot(t, y[1] / max(y[1]), label = "$" + name + "_2(t)$")
    plt.plot(t, h    / max(h),    '--', label = "Schrittweite", color = "black", linewidth = 1)

    plt.legend()
    plt.xlabel("$t$")
    plt.ylabel("Relation to $|| \cdot ||_\infty$")
    plt.grid(linestyle = ':')
    plt.show()

# %%
# Test 1

def f(t, Y):
    A = np.array([[-2, 1], [1, -2]])
    b = np.array([2 * np.sin(t), 2 * (np.cos(t) - np.sin(t))])
    return A @ Y + b

def f_Y(t, Y):
    A = np.array([[-2, 1], [1, -2]])
    return A

Y_0 = np.array([2, 3])

print("Test 1 ...")
test_implicit_euler(f, f_Y, Y_0)
test_practical_adaptive_algorithm(f, Y_0)

# Test 2

def f(t, Z):
    A = np.array([[-2, 1], [998, -999]])
    b = np.array([2 * np.sin(t), 999 * (np.cos(t) - np.sin(t))])
    return A @ Z + b

def f_Z(t, Z):
    A = np.array([[-2, 1], [998, -999]])
    return A

Z_0 = np.array([2, 3])

print("Test 2 ...")
test_implicit_euler(f, f_Z, Z_0, name = "z")
test_practical_adaptive_algorithm(f, Z_0, name = "z")
# Out:
# Test 1 ...
# initiating practical adaptive algorithm ...
#
# current status ... 0.0 %
# current time ..... 0 sec
#
# current status ... 2.59 %
# passed time ...... 1 sec
#
# current status ... 4.69 %
# passed time ...... 2 sec
#
# current status ... 6.87 %
# passed time ...... 3 sec
#
# current status ... 9.45 %
# passed time ...... 4 sec
#
# current status ... 12.16 %
# passed time ...... 5 sec
#
# current status ... 15.78 %
# passed time ...... 6 sec
#
# current status ... 19.02 %
# passed time ...... 7 sec
#
# current status ... 23.86 %
# passed time ...... 8 sec
#
# current status ... 27.91 %
# passed time ...... 9 sec
#
# current status ... 31.11 %
# passed time ...... 10 sec
#
# current status ... 33.75 %
# passed time ...... 11 sec
#
# current status ... 36.18 %
# passed time ...... 12 sec
#
# current status ... 38.23 %
# passed time ...... 13 sec
#
# current status ... 40.6 %
# passed time ...... 14 sec
#
# current status ... 43.2 %
# passed time ...... 15 sec
#
# current status ... 46.19 %
# passed time ...... 16 sec
#
# current status ... 50.53 %
# passed time ...... 17 sec
#
# current status ... 56.14 %
# passed time ...... 18 sec
#
# current status ... 59.14 %
# passed time ...... 19 sec
#
# current status ... 62.09 %
# passed time ...... 20 sec
#
# current status ... 64.58 %
# passed time ...... 21 sec
#
# current status ... 66.81 %
# passed time ...... 22 sec
#
# current status ... 68.85 %
# passed time ...... 23 sec
#
# current status ... 71.32 %
# passed time ...... 24 sec
#
# current status ... 74.13 %
# passed time ...... 25 sec
#
# current status ... 77.32 %
# passed time ...... 26 sec
#
# current status ... 80.77 %
# passed time ...... 27 sec
#
# current status ... 85.88 %
# passed time ...... 28 sec
#
# current status ... 89.88 %
# passed time ...... 29 sec
#
# current status ... 92.99 %
# passed time ...... 30 sec
#
# current status ... 95.66 %
# passed time ...... 31 sec
#
# current status ... 97.82 %
# passed time ...... 32 sec
#
# current status ... 99.69 %
# passed time ...... 33 sec
# C:\Users\richa\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Test 2 ...
# initiating practical adaptive algorithm ...
#
# current status ... 0.0 %
# current time ..... 0 sec
#
# current status ... 0.01 %
# passed time ...... 1 sec
#
# current status ... 0.02 %
# passed time ...... 2 sec
#
# current status ... 0.02 %
# passed time ...... 3 sec
#
# current status ... 0.03 %
# passed time ...... 4 sec
#
# current status ... 0.04 %
# passed time ...... 5 sec
#
# current status ... 0.05 %
# passed time ...... 6 sec
#
# current status ... 0.05 %
# passed time ...... 7 sec
#
# current status ... 0.06 %
# passed time ...... 8 sec
#
# current status ... 0.07 %
# passed time ...... 9 sec
#
# current status ... 0.07 %
# passed time ...... 10 sec
#
# current status ... 0.08 %
# passed time ...... 11 sec
#
# current status ... 0.09 %
# passed time ...... 12 sec
#
# current status ... 0.1 %
# passed time ...... 13 sec
#
# current status ... 0.1 %
# passed time ...... 14 sec
#
# current status ... 0.11 %
# passed time ...... 15 sec
#
# current status ... 0.12 %
# passed time ...... 16 sec
#
# current status ... 0.13 %
# passed time ...... 17 sec
#
# current status ... 0.13 %
# passed time ...... 18 sec
#
# current status ... 0.14 %
# passed time ...... 19 sec
#
# current status ... 0.15 %
# passed time ...... 20 sec
#
# current status ... 0.15 %
# passed time ...... 21 sec
#
# current status ... 0.16 %
# passed time ...... 22 sec
#
# current status ... 0.17 %
# passed time ...... 23 sec
#
# current status ... 0.18 %
# passed time ...... 24 sec
#
# current status ... 0.18 %
# passed time ...... 25 sec
#
# current status ... 0.19 %
# passed time ...... 26 sec
#
# current status ... 0.2 %
# passed time ...... 27 sec
#
# current status ... 0.2 %
# passed time ...... 28 sec
#
# current status ... 0.21 %
# passed time ...... 29 sec
#
# current status ... 0.22 %
# passed time ...... 30 sec
#
# current status ... 0.23 %
# passed time ...... 31 sec
#
# current status ... 0.23 %
# passed time ...... 32 sec
#
# current status ... 0.24 %
# passed time ...... 33 sec
#
# current status ... 0.25 %
# passed time ...... 34 sec
#
# current status ... 0.26 %
# passed time ...... 35 sec
#
# current status ... 0.26 %
# passed time ...... 36 sec
#
# current status ... 0.27 %
# passed time ...... 37 sec
#
# current status ... 0.28 %
# passed time ...... 38 sec
#
# current status ... 0.28 %
# passed time ...... 39 sec
#
# current status ... 0.29 %
# passed time ...... 40 sec
#
# current status ... 0.3 %
# passed time ...... 41 sec
#
# current status ... 0.31 %
# passed time ...... 42 sec
#
# current status ... 0.32 %
# passed time ...... 43 sec
#
# current status ... 0.32 %
# passed time ...... 44 sec
#
# current status ... 0.33 %
# passed time ...... 45 sec
#
# current status ... 0.34 %
# passed time ...... 46 sec
#
# current status ... 0.35 %
# passed time ...... 47 sec
#
# current status ... 0.35 %
# passed time ...... 48 sec
#
# current status ... 0.36 %
# passed time ...... 49 sec
#
# current status ... 0.37 %
# passed time ...... 50 sec
#
# current status ... 0.37 %
# passed time ...... 51 sec
#
# current status ... 0.38 %
# passed time ...... 52 sec
#
# current status ... 0.39 %
# passed time ...... 53 sec
#
# current status ... 0.39 %
# passed time ...... 54 sec
#
# current status ... 0.4 %
# passed time ...... 55 sec
#
# current status ... 0.41 %
# passed time ...... 56 sec
#
# current status ... 0.42 %
# passed time ...... 57 sec
#
# current status ... 0.42 %
# passed time ...... 58 sec
#
# current status ... 0.43 %
# passed time ...... 59 sec
#
# current status ... 0.44 %
# passed time ...... 60 sec
#
# current status ... 0.44 %
# passed time ...... 61 sec
#
# current status ... 0.45 %
# passed time ...... 62 sec
#
# current status ... 0.46 %
# passed time ...... 63 sec
#
# current status ... 0.46 %
# passed time ...... 64 sec
#
# current status ... 0.47 %
# passed time ...... 65 sec
#
# current status ... 0.48 %
# passed time ...... 66 sec
#
# current status ... 0.49 %
# passed time ...... 67 sec
#
# current status ... 0.49 %
# passed time ...... 68 sec
#
# current status ... 0.5 %
# passed time ...... 69 sec
#
# current status ... 0.51 %
# passed time ...... 70 sec
#
# current status ... 0.51 %
# passed time ...... 71 sec
#
# current status ... 0.52 %
# passed time ...... 72 sec
#
# current status ... 0.53 %
# passed time ...... 73 sec
#
# current status ... 0.53 %
# passed time ...... 74 sec
#
# current status ... 0.54 %
# passed time ...... 75 sec
#
# current status ... 0.55 %
# passed time ...... 76 sec
#
# current status ... 0.56 %
# passed time ...... 77 sec
#
# current status ... 0.56 %
# passed time ...... 78 sec
#
# current status ... 0.57 %
# passed time ...... 79 sec
#
# current status ... 0.58 %
# passed time ...... 80 sec
#
# current status ... 0.58 %
# passed time ...... 81 sec
#
# current status ... 0.59 %
# passed time ...... 82 sec
#
# current status ... 0.59 %
# passed time ...... 83 sec
#
# current status ... 0.6 %
# passed time ...... 84 sec
#
# current status ... 0.61 %
# passed time ...... 85 sec
#
# current status ... 0.62 %
# passed time ...... 86 sec
#
# current status ... 0.62 %
# passed time ...... 87 sec
#
# current status ... 0.63 %
# passed time ...... 88 sec
#
# current status ... 0.64 %
# passed time ...... 89 sec
#
# current status ... 0.64 %
# passed time ...... 90 sec
#
# current status ... 0.65 %
# passed time ...... 91 sec
#
# current status ... 0.66 %
# passed time ...... 92 sec
#
# current status ... 0.67 %
# passed time ...... 93 sec
#
# current status ... 0.67 %
# passed time ...... 94 sec
#
# current status ... 0.68 %
# passed time ...... 95 sec
#
# current status ... 0.69 %
# passed time ...... 96 sec
#
# current status ... 0.7 %
# passed time ...... 97 sec
#
# current status ... 0.7 %
# passed time ...... 98 sec
#
# current status ... 0.71 %
# passed time ...... 99 sec
#
# current status ... 0.72 %
# passed time ...... 100 sec
#
# current status ... 0.72 %
# passed time ...... 101 sec
#
# current status ... 0.73 %
# passed time ...... 102 sec
#
# current status ... 0.74 %
# passed time ...... 103 sec
#
# current status ... 0.75 %
# passed time ...... 104 sec
#
# current status ... 0.75 %
# passed time ...... 105 sec
#
# current status ... 0.76 %
# passed time ...... 106 sec
#
# current status ... 0.77 %
# passed time ...... 107 sec
#
# current status ... 0.77 %
# passed time ...... 108 sec
#
# current status ... 0.78 %
# passed time ...... 109 sec
#
# current status ... 0.79 %
# passed time ...... 110 sec
#
# current status ... 0.8 %
# passed time ...... 111 sec
#
# current status ... 0.8 %
# passed time ...... 112 sec
#
# current status ... 0.81 %
# passed time ...... 113 sec
#
# current status ... 0.82 %
# passed time ...... 114 sec
#
# current status ... 0.82 %
# passed time ...... 115 sec
#
# current status ... 0.83 %
# passed time ...... 116 sec
#
# current status ... 0.84 %
# passed time ...... 117 sec
#
# current status ... 0.84 %
# passed time ...... 118 sec
#
# current status ... 0.85 %
# passed time ...... 119 sec
#
# current status ... 0.85 %
# passed time ...... 120 sec
#
# current status ... 0.86 %
# passed time ...... 121 sec
#
# current status ... 0.87 %
# passed time ...... 122 sec
#
# current status ... 0.87 %
# passed time ...... 123 sec
#
# current status ... 0.88 %
# passed time ...... 124 sec
#
# current status ... 0.89 %
# passed time ...... 125 sec
#
# current status ... 0.89 %
# passed time ...... 126 sec
#
# current status ... 0.9 %
# passed time ...... 127 sec
#
# current status ... 0.91 %
# passed time ...... 128 sec
#
# current status ... 0.91 %
# passed time ...... 129 sec
#
# current status ... 0.92 %
# passed time ...... 130 sec
#
# current status ... 0.93 %
# passed time ...... 131 sec
#
# current status ... 0.94 %
# passed time ...... 132 sec
#
# current status ... 0.94 %
# passed time ...... 133 sec
#
# current status ... 0.95 %
# passed time ...... 134 sec
#
# current status ... 0.95 %
# passed time ...... 135 sec
#
# current status ... 0.96 %
# passed time ...... 136 sec
#
# current status ... 0.97 %
# passed time ...... 137 sec
#
# current status ... 0.97 %
# passed time ...... 138 sec
#
# current status ... 0.98 %
# passed time ...... 139 sec
#
# current status ... 0.98 %
# passed time ...... 140 sec
#
# current status ... 0.99 %
# passed time ...... 141 sec
#
# current status ... 0.99 %
# passed time ...... 142 sec
#
# current status ... 1.0 %
# passed time ...... 143 sec
#
# current status ... 1.01 %
# passed time ...... 144 sec
#
# current status ... 1.01 %
# passed time ...... 145 sec
#
# current status ... 1.02 %
# passed time ...... 146 sec
#
# current status ... 1.03 %
# passed time ...... 147 sec
#
# current status ... 1.03 %
# passed time ...... 148 sec
#
# current status ... 1.04 %
# passed time ...... 149 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b9a202076b92> in <module>
#      31 print("Test 2 ...")
#      32 test_implicit_euler(f, f_Z, Z_0, name = "z")
# ---> 33 test_practical_adaptive_algorithm(f, Z_0, name = "z")
#
# <ipython-input-6-05810f72c436> in test_practical_adaptive_algorithm(f, y_0, name)
#      33     p   = 4
#      34
# ---> 35     t, h, y = practical_adaptive_algorithm(t_0, T, y_0, f, c, A, b_1, b_2, p, tau, h, h_min, eta, rho)
#      36
#      37     # ---------------- #
#
# <ipython-input-5-68045cebebc7> in practical_adaptive_algorithm(t_0, T, y_0, f, c, A, b_1, b_2, p, tau, h, h_min, lambda_, rho)
#      49
#      50         for i in range(m):
# ---> 51             k[i] = f(t[-1] + c[i] * h, y[-1] + h * (A[i][:i] @ k[:i]))
#      52
#      53         F_1 = b_1 @ k
#
# <ipython-input-7-b9a202076b92> in f(t, Z)
#      21     A = np.array([[-2, 1], [998, -999]])
#      22     b = np.array([2 * np.sin(t), 999 * (np.cos(t) - np.sin(t))])
# ---> 23     return A @ Z + b
#      24
#      25 def f_Z(t, Z):
#
# KeyboardInterrupt:
