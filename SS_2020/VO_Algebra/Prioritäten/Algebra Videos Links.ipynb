# %%
import requests
import bs4

# %%
playlist = r'https://www.youtube.com/playlist?list=PLnaikpgfX9NjEbJL4yYQFemHxsDQnZo2Q'

# %%
source = requests.get(playlist)

# %%
soup = bs4.BeautifulSoup(source.content, 'html.parser')

# %%
print(soup.find('body').prettify())
# Out:
# <body dir="ltr">
#  <script>
#   if (window.ytcsi) {window.ytcsi.tick("bs", null, '');}    ytcfg.set('initialBodyClientWidth', document.body.clientWidth);
#
#     window.ytcfg.set('SERVICE_WORKER_KILLSWITCH', false);
#  </script>
#  <script>
# ...
